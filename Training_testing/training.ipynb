# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.iloc[:, 1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:, -1]

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 2    5.3  121.0
# 13   6.4  116.0
# 30   7.6  128.0
# 37   8.1  149.0
# 4    5.8  142.0
# ..   ...    ...
# 74   6.7  154.0
# 62   6.0  102.0
# 93   6.8  112.0
# 14   6.1  103.0
# 36   5.7  140.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 70   6.3  127.0
# 29   7.0  112.0
# 72   7.3  116.0
# 6    5.7  143.0
# 80   4.9  196.0
# 22   4.9  120.0
# 5    7.1   48.0
# 69   8.5  120.0
# 8    6.1  156.0
# 41   5.4  114.0

# %%
y_train
# Out:
# 2     0
# 13    1
# 30    1
# 37    1
# 4     0
#      ..
# 74    1
# 62    0
# 93    1
# 14    0
# 36    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 70    1
# 29    1
# 72    1
# 6     0
# 80    0
# 22    0
# 5     1
# 69    1
# 8     0
# 41    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.5759998 , -0.05974135],
#        [ 0.39214927, -0.18420249],
#        [ 1.44831189,  0.11450425],
#        [ 1.88837965,  0.63724105],
#        [-0.13593204,  0.46299545],
#        [ 0.83221703,  0.38831877],
#        [ 1.18427123, -0.93096935],
#        [ 0.30413572,  0.11450425],
#        [ 0.39214927,  0.43810322],
#        [ 0.74420347, -0.83140044],
#        [-0.66401335,  2.50415821],
#        [ 0.04009506,  0.63724105],
#        [ 0.92023058,  1.284439  ],
#        [-1.10408111, -0.05974135],
#        [ 1.36029834,  0.86127111],
#        [-0.22394559,  0.21407317],
#        [-0.928054  ,  0.78659443],
#        [-0.928054  ,  0.26385762],
#        [ 1.00824413,  0.68702551],
#        [-0.84004045, -0.13441803],
#        [-0.7520269 ,  1.30933123],
#        [-0.928054  ,  0.68702551],
#        [-1.01606756,  0.98573226],
#        [-1.10408111, -1.77730513],
#        [-0.48798625,  0.38831877],
#        [ 0.30413572, -0.50780147],
#        [ 0.92023058, -1.47859838],
#        [-0.928054  , -1.55327507],
#        [ 0.83221703, -0.68204707],
#        [-1.36812176, -2.02622741],
#        [ 1.44831189, -0.85629267],
#        [ 0.92023058,  1.88185249],
#        [ 0.65618992,  1.4586846 ],
#        [-1.01606756,  0.43810322],
#        [-0.66401335,  0.9359478 ],
#        [-0.7520269 , -1.42881393],
#        [ 0.48016282,  0.91105557],
#        [-0.48798625,  0.28874985],
#        [-1.19209466,  0.56256437],
#        [-1.36812176,  0.63724105],
#        [-0.66401335, -0.33355586],
#        [-1.45613531,  1.90674472],
#        [ 0.04009506,  0.01493534],
#        [ 0.21612217, -0.25887918],
#        [-0.66401335,  0.21407317],
#        [ 0.12810861, -1.45370616],
#        [ 0.04009506, -1.95155073],
#        [ 0.12810861,  0.21407317],
#        [ 0.48016282, -0.83140044],
#        [-0.7520269 ,  0.11450425],
#        [-2.33627083,  1.48357683],
#        [-1.01606756, -0.28377141],
#        [-0.13593204,  1.06040894],
#        [-1.72017597, -1.20478387],
#        [ 0.92023058,  0.38831877],
#        [-2.16024373,  2.72818826],
#        [ 0.74420347,  0.43810322],
#        [ 1.36029834, -1.55327507],
#        [-0.48798625, -0.40823255],
#        [ 0.48016282, -2.15068856],
#        [ 0.12810861, -1.0554305 ],
#        [-1.80818952, -0.35844809],
#        [ 1.62433899, -0.23398695],
#        [ 1.18427123, -1.82708959],
#        [ 0.04009506, -1.42881393],
#        [ 0.83221703,  0.36342654],
#        [ 0.56817637, -0.08463358],
#        [-0.66401335, -0.83140044],
#        [ 0.56817637,  0.36342654],
#        [ 1.18427123,  0.33853431],
#        [-0.04791849, -0.43312478],
#        [-0.5759998 , -0.23398695],
#        [ 1.88837965,  1.06040894],
#        [-1.01606756,  1.13508563],
#        [-0.84004045, -1.50349061],
#        [-0.22394559,  1.13508563],
#        [-0.84004045, -0.80650821],
#        [-1.10408111, -0.90607712],
#        [ 0.48016282,  0.16428871],
#        [ 0.74420347, -0.00995689],
#        [ 2.06440675,  1.1101934 ],
#        [ 1.80036609, -1.10521495],
#        [ 1.36029834,  0.16428871],
#        [ 1.27228478,  0.21407317],
#        [-1.72017597, -0.58247815],
#        [ 0.65618992,  0.7617022 ],
#        [ 0.04009506, -0.53269369],
#        [ 0.74420347, -0.28377141],
#        [ 0.12810861, -0.50780147],
#        [-0.22394559,  0.413211  ]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.01818482,  0.05054983],
#        [ 0.61828402, -0.37069878],
#        [ 0.89105639, -0.25836582],
#        [-0.56372955,  0.49988169],
#        [-1.29112252,  1.98829345],
#        [-1.29112252, -0.14603285],
#        [ 0.70920814, -2.16802619],
#        [ 1.98214584, -0.14603285],
#        [-0.20003307,  0.86496382],
#        [-0.83650191, -0.3145323 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 70    1
# 29    1
# 72    1
# 6     0
# 80    0
# 22    0
# 5     1
# 69    1
# 8     0
# 41    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting scipy>=1.16.3 (from mlxtend)
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting numpy>=2.3.5 (from mlxtend)
#   Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.3 (from mlxtend)
#   Downloading pandas-3.0.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting scikit-learn>=1.8.0 (from mlxtend)
#   Downloading scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Downloading matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
# Collecting joblib>=1.5.2 (from mlxtend)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.28.2 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=9 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lucky/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Collecting narwhals>=2.0.1 (from scikit-learn>=1.8.0->mlxtend)
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/lucky/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/lucky/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.16.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.5 MB/s eta 0:00:00? eta -:--:--
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 2.5 MB/s eta 0:00:0031m2.4 MB/s eta 0:00:01
# Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 5.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading pandas-3.0.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 6.4 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 6.2 MB/s eta 0:00:000:00:010:00:01:01
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 6.3 MB/s eta 0:00:006.3 MB/s eta 0:00:01
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Installing collected packages: numpy, narwhals, joblib, scipy, pandas, scikit-learn, matplotlib, mlxtend
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.2
#     Uninstalling matplotlib-3.9.2:
#       Successfully uninstalled matplotlib-3.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.5.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.5.1 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.5.1 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.18.0 which is incompatible.
# veros 1.6.2 requires numpy<=2.4.2,>=1.13, but you have numpy 2.5.1 which is incompatible.
# veros 1.6.2 requires scipy<=1.17.1, but you have scipy 1.18.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.5.1 which is incompatible.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.5.1 which is incompatible.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# streamlit 1.37.1 requires pandas<3,>=1.3.0, but you have pandas 3.0.5 which is incompatible.
# Successfully installed joblib-1.5.3 matplotlib-3.11.1 mlxtend-0.25.0 narwhals-2.24.0 numpy-2.5.1 pandas-3.0.5 scikit-learn-1.9.0 scipy-1.18.0

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl','wb'))

# %%
with open('model.pkl',"rb") as file:
    loaded_model = pickle.load(file)

print(loaded_model)
# Out:
# LogisticRegression()
